# %% [markdown]
# <a href="https://colab.research.google.com/github/b-ukusi/cystellaai/blob/main/cysella.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cystella

# %% [markdown]
# # Loading data

# %%
import pandas as pd

# Raw URLs for CSV files
url_inventory = 'https://raw.githubusercontent.com/b-ukusi/datasets/main/Resources%20Inventory%20Cost%20Sheet.csv'
url_cyst = 'https://raw.githubusercontent.com/b-ukusi/datasets/main/Ovarian%20Cyst%20Track%20Data.csv'
df_inventory = pd.read_csv(url_inventory)
df_cyst      = pd.read_csv(url_cyst)

# 👇 Here: drop columns that are entirely empty (no data in any row)
df_inventory = df_inventory.loc[:, df_inventory.notna().any(axis=0)]
df_cyst      = df_cyst.loc[:,      df_cyst.notna().any(axis=0)]

# Configure full display
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)


# Show data
print("Inventory data:")
display(df_inventory.head(100))

print("\nCyst data:")
display(df_cyst.head(100))
# Out:
# Inventory data:
#                               Facility     Region         Category  \
# 0           Pumwani Maternity Hospital   Pumwani       Medications
# 1    Kakamega County Referral Hospital  Kakamega       Medications
# 2            Machakos Level 5 Hospital   Machakos      Medications
# 3                Embu Level 5 Hospital      Embu       Medications
# 4              Mombasa County Hospital    Mombasa      Medications
# 5           Pumwani Maternity Hospital      Embu       Medications
# 6                Embu Level 5 Hospital      Embu   Lab Consumables
# 7                Embu Level 5 Hospital      Embu       Medications
# 8                Embu Level 5 Hospital      Embu       Consumables
# 9     Kericho County Referral Hospital     NAKURU  Lab Consumables
# 10       Loitoktok Sub-County Hospital  Loitoktok      Medications
# 11             Mombasa County Hospital    Mombasa      Consumables
# 12           Machakos Level 5 Hospital   Machakos      Medications
# ...

# %%
df_cyst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Patient ID                 100 non-null    object
#  1   Age                        100 non-null    int64
#  2   Menopause Status           100 non-null    object
#  3   Cyst Size cm               100 non-null    float64
#  4   Cyst Growth Rate cm/month  100 non-null    float64
#  5   CA 125 Level               100 non-null    int64
#  6   Ultrasound Features        100 non-null    object
#  7   Reported Symptoms          100 non-null    object
#  8   Recommended Management     100 non-null    object
#  9   Date of Exam               100 non-null    object
#  10  Region                     100 non-null    object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 8.7+ KB

# %%
df_inventory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 997 entries, 0 to 996
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Facility         100 non-null    object
#  1   Region           100 non-null    object
#  2   Category         100 non-null    object
#  3   Item             100 non-null    object
#  4   Cost (KES)       100 non-null    float64
#  5   Available Stock  100 non-null    float64
# dtypes: float64(2), object(4)
# memory usage: 46.9+ KB

# %%
# Out:
# Variable        Type         Data/Info
# --------------------------------------
# df_cyst         DataFrame       Patient ID  Age Menopa<...>  2025-05-10     Kisumu
# df_inventory    DataFrame                             <...>   NaN              NaN
# path            str          https://drive.google.com/<...>_c_Mn8JgVckOn7_yD8tEnd20b
# pd              module       <module 'pandas' from '/u<...>ages/pandas/__init__.py'>
# url_cyst        str          https://raw.githubusercon<...>20Cyst%20Track%20Data.csv
# url_inventory   str          https://raw.githubusercon<...>entory%20Cost%20Sheet.csv

# %% [markdown]
# # Data prep

# %% [markdown]
# ## understanding data set

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-19-3089318408.py in <cell line: 0>()
# ----> 1 df.info()
#
# NameError: name 'df' is not defined
